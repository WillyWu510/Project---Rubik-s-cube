# %%
import import_ipynb
import facelet as Fc

URF = 0
UFL = 1
ULB = 2
UBR = 3
DFR = 4
DLF = 5
DBL = 6
DRB = 7

corner_values = (
    URF,
    UFL,
    ULB,
    UBR,
    DFR,
    DLF,
    DBL,
    DRB,
)

corner_keys = (
    'URF',
    'UFL',
    'ULB',
    'UBR',
    'DFR',
    'DLF',
    'DBL',
    'DRB',
)

# make a dict
corners = {
    'URF': URF,
    'UFL': UFL,
    'ULB': ULB,
    'UBR': UBR,
    'DFR': DFR,
    'DLF': DLF,
    'DBL': DBL,
    'DRB': DRB,
}

# For transition from cubie to facelet
corner_facelets = {
    
    'URF':[Fc.facelets['U9'],Fc.facelets['R1'],Fc.facelets['F3']] ,
    'UFL':[Fc.facelets['U7'],Fc.facelets['F1'],Fc.facelets['L3']] ,
    'ULB':[Fc.facelets['U1'],Fc.facelets['L1'],Fc.facelets['B3']] ,
    'UBR':[Fc.facelets['U3'],Fc.facelets['B1'],Fc.facelets['R3']] ,
    'DFR':[Fc.facelets['D3'],Fc.facelets['F9'],Fc.facelets['R7']] ,
    'DLF':[Fc.facelets['D1'],Fc.facelets['L9'],Fc.facelets['F7']] ,
    'DBL':[Fc.facelets['D7'],Fc.facelets['B9'],Fc.facelets['L7']] ,
    'DRB':[Fc.facelets['D9'],Fc.facelets['R9'],Fc.facelets['B7']]
}
